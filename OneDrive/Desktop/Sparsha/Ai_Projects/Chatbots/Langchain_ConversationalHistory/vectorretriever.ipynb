# %%
#pip install langchain
#pip install langchain-chroma
#pip install langchain_groq

# %%
from langchain_core.documents import Document
documents = [
    Document(
        page_content="Dogs are great companions, known for their loyalty and friendliness.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Cats are independent animals, often valued for their grace and agility.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Parrots are colorful birds, famous for their ability to mimic human speech.",
        metadata={"source": "bird-pets-doc"},
    ),
]

# %%
documents
# Out:
# [Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent animals, often valued for their grace and agility.'),
#  Document(metadata={'source': 'bird-pets-doc'}, page_content='Parrots are colorful birds, famous for their ability to mimic human speech.')]

# %%
import os
from dotenv import load_dotenv
load_dotenv()
from langchain_groq import ChatGroq

groq_api_key = os.getenv("GROQ_API_KEY")
os.environ["HF_Token"] = os.getenv("HF_TOKEN")
llm = ChatGroq(groq_api_key=groq_api_key, model = "Llama3-8b-8192")
llm
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x0000021AABAF8400>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000021AABAC9930>, model_name='Llama3-8b-8192', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
pip install langchain-huggingface
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting langchain-huggingface
#   Downloading langchain_huggingface-0.3.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: huggingface-hub>=0.33.4 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from langchain-huggingface) (0.34.4)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from langchain-huggingface) (0.21.4)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.70 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from langchain-huggingface) (0.3.74)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (4.14.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (6.0.2)
# Requirement already satisfied: packaging>=20.9 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (25.0)
# Requirement already satisfied: requests in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (4.67.1)
# Requirement already satisfied: filelock in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (2025.7.0)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.4.15)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (9.1.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (3.11.2)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.24.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.0.0)
# Requirement already satisfied: httpcore==1.* in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.0.9)
# Requirement already satisfied: certifi in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2025.8.3)
# Requirement already satisfied: idna in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (3.10)
# Requirement already satisfied: anyio in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (4.10.0)
# Requirement already satisfied: h11>=0.16 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.16.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.33.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from requests->huggingface-hub>=0.33.4->langchain-huggingface) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from requests->huggingface-hub>=0.33.4->langchain-huggingface) (3.4.3)
# Requirement already satisfied: colorama in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\spars\onedrive\desktop\sparsha\ai_projects\chatbots\langchain_conversationalhistory\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.3.1)
# Installing collected packages: langchain-huggingface
# Successfully installed langchain-huggingface-0.3.1
# WARNING: You are using pip version 21.2.3; however, version 25.2 is available.
# You should consider upgrading via the 'c:\Users\spars\OneDrive\Desktop\Sparsha\Ai_Projects\Chatbots\Langchain_ConversationalHistory\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
#Creating embeddings using huggingface
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model = "all-MiniLM-L6-v2")

# %%
#VEctorStore

from langchain_chroma import Chroma
