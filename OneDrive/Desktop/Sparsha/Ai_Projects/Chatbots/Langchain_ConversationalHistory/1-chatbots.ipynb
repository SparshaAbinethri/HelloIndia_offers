# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq
model = ChatGroq(model="Gemma2-9b-It", groq_api_key=GROQ_API_KEY)  # Initialize the Groq chat
model
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x0000016F82A3B130>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000016F82A38CD0>, model_name='Gemma2-9b-It', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_core.messages import HumanMessage
model.invoke([HumanMessage(content = "Hi, My name is Sparsha and I'm developing AI Projects")])
# Out:
# AIMessage(content="Hi Sparsha,\n\nIt's great to meet you! AI project development is an exciting field. \n\nWhat kind of AI projects are you working on? I'd love to hear more about them. \n\nPerhaps I can be of help? I can assist with:\n\n* **Brainstorming ideas:** If you're stuck, I can help you generate new project concepts.\n* **Research:** I can provide information on various AI techniques, algorithms, and tools.\n* **Code generation:** I can help you write code in different programming languages.\n* **Debugging:** I can help you identify and fix errors in your code.\n* **Explaining concepts:** I can explain complex AI concepts in a clear and concise way.\n\n\nLet me know how I can be of assistance!\n", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 167, 'prompt_tokens': 23, 'total_tokens': 190, 'completion_time': 0.303636364, 'prompt_time': 0.001342399, 'queue_time': 0.076922321, 'total_time': 0.304978763}, 'model_name': 'Gemma2-9b-It', 'system_fing
# ...

# %%
from langchain_core.messages import AIMessage
model.invoke([
    HumanMessage(content = "Hi, My name is Sparsha and I'm developing AI Projects"),
    AIMessage(content = "Hi Sparsha, it's great to meet you! \n\nDeveloping AI projects is exciting. What kind of AI projects are you working on? \n\nTell me more about them. I'm always eager to learn about new AI applications and maybe even offer some help or suggestions if you need them. 😊")
    ,
    HumanMessage(content = "Hey What's my name and what do I do")])
# Out:
# AIMessage(content="You are Sparsha, and you are developing AI projects!  \n\nIs there anything specific you'd like to know or talk about regarding your AI projects? I'm here to help!\n", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 107, 'total_tokens': 149, 'completion_time': 0.076363636, 'prompt_time': 0.002802449, 'queue_time': 0.074574431, 'total_time': 0.079166085}, 'model_name': 'Gemma2-9b-It', 'system_fingerprint': 'fp_10c08bf97d', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--276576cf-26ae-450c-9f41-d99ac937ce5e-0', usage_metadata={'input_tokens': 107, 'output_tokens': 42, 'total_tokens': 149})

# %%
#Message history
# !pip install langchain-community
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 25.2 is available.
# You should consider upgrading via the 'C:\Users\spars\OneDrive\Desktop\Sparsha\Ai_Projects\Chatbots\Langchain_ConversationalHistory\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# ...

# %%
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

store = {}

def get_session_history(session_id:str)->BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]

with_message_history = RunnableWithMessageHistory(model,get_session_history)

# %%
config = {"configurable":{"session_id":"chat1"}}

# %%
response = with_message_history.invoke(
    [HumanMessage(content = "Hi, My name is Sparsha and I'm developing AI Projects")],
    config = config
)
response.content
# Out:
# "Hi Sparsha, it's nice to meet you! That's awesome, AI project development is a really exciting field.\n\nWhat kind of AI projects are you working on?  \n\nI'd love to hear more about them and maybe even offer some help if I can. For example, I can:\n\n* **Brainstorm ideas:** If you're stuck on what to build, I can help you come up with some creative concepts.\n* **Provide information:** I have access to a vast amount of knowledge about AI and can answer your questions about specific techniques, tools, or concepts.\n* **Generate code:** I can help you write code for your projects, although I'm still learning and best at simpler tasks.\n* **Offer feedback:** If you have a project in progress, I can give you feedback on your ideas and code.\n\n\nTell me more about what you're doing!\n"

# %%
##Chaging the config -- session id (it will forget previous info since we are changing the session id/config)
config1 = {"configurable":{"session_id":"chat2"}}
response = with_message_history.invoke([HumanMessage(content = "Hey, What's my name and what do I do")], config = config1)
response.content
# Out:
# "As an AI, I have no memory of past conversations and no information about you. To know your name and what you do, you'll have to tell me! 😊  \n\nWhat's your name? And what do you like to do?\n"

# %%
##prompt Templates

from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
prompt = ChatPromptTemplate.from_messages([
    ("system",
     "You are a helpful assistant. Answer all the questions to the best of your ability"),
    MessagesPlaceholder(variable_name = "messages")

])

chain = prompt | model

# %%
chain.invoke({"messages":[HumanMessage(content = "Hi, My name is Sparsha")]})
# Out:
# AIMessage(content="Hi Sparsha, it's nice to meet you!  \n\nI'm happy to help with any questions you have. What can I do for you today? 😊  \n", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 32, 'total_tokens': 71, 'completion_time': 0.070909091, 'prompt_time': 0.00147689, 'queue_time': 0.074677259, 'total_time': 0.072385981}, 'model_name': 'Gemma2-9b-It', 'system_fingerprint': 'fp_10c08bf97d', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--a690beb1-caf7-4811-8b2b-5f9dc2468bc7-0', usage_metadata={'input_tokens': 32, 'output_tokens': 39, 'total_tokens': 71})

# %%
with_message_history = RunnableWithMessageHistory(chain, get_session_history)
config = {"configurable":{"session_id":"chat1"}}
response = with_message_history.invoke(
    [HumanMessage(content = "Hi My name is Sparsha")],
    config = config
)

response.content
# Out:
# "Hi Sparsha, it's nice to meet you! \n\nWhat can I do for you today? 😊  Are you working on any cool AI projects?\n"

# %%
##Adding more Complexity to the prompt

prompt = ChatPromptTemplate.from_messages([
    ("system",
     "You are a helpful assistant. Answer all the questions to the best of your ability in  {language})"),
    MessagesPlaceholder(variable_name = "messages")

])

chain = prompt | model

# %%
response = chain.invoke({"messages":
    [HumanMessage(content = "Hi My name is Sparsha")],
    "language" : "Telugu"
}
)

response.content
# Out:
# 'ప్రశాంత్! మీకు నేను సహాయకరమైన సహాయకుడిని. ఏ విషయంలోనైనా మీ ప్రశ్నలకు సమాధానం ఇవ్వడానికి ప్రయత్నిస్తాను. 😊 \n\n'

# %%
with_message_history = RunnableWithMessageHistory(chain,
                                                  get_session_history,
                                                  input_messages_key = "messages")

# %%
config = {"configurable":{"session_id":"chat4"}}
response = with_message_history.invoke(
    {'messages':[HumanMessage(content = "Hi, I am Sparsha")],"language":"Hindi"},
    config = config
)

response.content
# Out:
# 'नमस्ते Sparsha! 👋 \n\nमैं आपकी मदद करने के लिए तैयार हूँ। आप मुझसे क्या पूछना चाहते हैं? 😊 \n'

# %% [markdown]
# If left unmanaged, the list of messages will grow unbounded and potentially overflow teh context window of the LLM. Therefore, it is important to add a step that limits the size of the messages you are passing in
#
#
# 'Trim_messages': It helps to reduce how many messages we're sending to the model. The trimmer allows us to specify how many tokens we want to keep, along with other parameters like if we want to always keep the system message and whether to allow partial messages

# %%
# %pip install transformers
# Out:
# ...
#
# ...
# WARNING: You are using pip version 21.2.3; however, version 25.2 is available.
# You should consider upgrading via the 'c:\Users\spars\OneDrive\Desktop\Sparsha\Ai_Projects\Chatbots\Langchain_ConversationalHistory\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
from langchain_core.messages import SystemMessage,trim_messages
trimmer=trim_messages(
    max_tokens=45,
    strategy="last",
    token_counter=model,
    include_system=True,
    allow_partial=False,
    start_on="human"
)
messages = [
    SystemMessage(content="you're a good assistant"),
    HumanMessage(content="hi! I'm bob"),
    AIMessage(content="hi!"),
    HumanMessage(content="I like vanilla ice cream"),
    AIMessage(content="nice"),
    HumanMessage(content="whats 2 + 2"),
    AIMessage(content="4"),
    HumanMessage(content="thanks"),
    AIMessage(content="no problem!"),
    HumanMessage(content="having fun?"),
    AIMessage(content="yes!"),
]
trimmer.invoke(messages)
# Out:
# [SystemMessage(content="you're a good assistant", additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='I like vanilla ice cream', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='nice', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='whats 2 + 2', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='4', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='thanks', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='no problem!', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='having fun?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='yes!', additional_kwargs={}, response_metadata={})]

# %%
from operator import itemgetter
from langchain_core.runnables import RunnablePassthrough

chain= (
    RunnablePassthrough.assign(messages = itemgetter("messages")|trimmer) | prompt | model)

response = chain.invoke({
    "messages": messages + [HumanMessage(content = "What Ice cream do I like")],
    "language": "English"
})
response.content
# Out:
# "As an AI, I don't have access to your personal information, including your ice cream preferences.  What's your favorite flavor? 😊  \n\n\n\n\n"

# %%
with_message_history = RunnableWithMessageHistory(chain,
                                                  get_session_history,
                                                  input_messages_key = "messages")
config = {"configurable":{"session_id":"chats"}}

# %%
response = with_message_history.invoke(
    {"messages":messages + [HumanMessage(content = "what's my name?")],
     "language":"English"},
     config = config,
)
response.content
# Out:
# "As a helpful assistant, I don't have access to past conversations or any personal information about you, including your name. \n\nWould you like to tell me your name? 😄  \n"
